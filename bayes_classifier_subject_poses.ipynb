# %% [markdown]
# <a href="https://colab.research.google.com/github/siddharthtelang/Face-Detection/blob/main/bayes_classifier_subject_poses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.decomposition import PCA

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-336b5b86-cea1-4563-850a-74b4f2f08949" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-336b5b86-cea1-4563-850a-74b4f2f08949">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pose.mat to pose.mat

# %%
# load the data
data = sio.loadmat('pose.mat')

# %%
# get all the poses for different subjects
poses = data.get('pose')
poses.shape
# Out:
# (48, 40, 13, 68)

# %%
fig, ax_array = plt.subplots(nrows=10, ncols=5, figsize=(20,20))

# flatten the array of axes, which makes them easier to iterate through and assign
ax_array = ax_array.flatten()
c = 0
d = 0
# plot some poses
for i, ax in enumerate(ax_array):
    if c == 13:
        c = 0
        d += 1
    ax.imshow(poses[:,:,c,d])
    c+=1

# %% [markdown]
# # Build up the training and testing data

# %%
# import random
# def get_training_and_testing_data(data, subjects, types):
#     size = data.shape[0]*data.shape[1]
#     training_data = []
#     testing_data = []
#     training_size = math.ceil(types*(2/3))
#     testing_size = types - training_size
#     for i in range(subjects):
#         temp = dict()
#         temp['data'] = []

#         for j in range(types):
#             temp['data'].append((data[:,:,j,i]).reshape(1, size))

#         random.shuffle(temp['data']) # shuffle the data
#         tr = temp['data'][:training_size] # training batch
#         te = temp['data'][training_size:] # testing batch
#         training_data.append({'class': i, 'data':tr})
#         testing_data.append({'class': i, 'data': te})
    
#     return training_data, testing_data

# %%
# train, test = get_training_and_testing_data(poses, subjects=68, types=13)

# %% [markdown]
# ## Flatten the data set

# %%
subjects = 68
types = 13
flattened = np.zeros(shape=(subjects*types, poses.shape[0]*poses.shape[1]))
print(flattened.shape)
c = 0
d = 0
for i in range(flattened.shape[0]):
    if c == types:
        c = 0
        d += 1
    temp = poses[:,:,c,d]
    flattened[i] = temp.flatten()
    c += 1
# Out:
# (884, 1920)

# %% [markdown]
# ## Check for PCA 95% retention

# %%
pca = PCA().fit(flattened)
plt.figure()
plt.plot(pca.explained_variance_ratio_.cumsum(), lw=3)

# %%
# above figure shows 95% retention at dimension >= 200
# we will apply PCA to reduce dimension to 200
usePCA = True
pca = PCA(300)
projected = pca.fit_transform(flattened)
print(projected.shape)
# Out:
# (884, 300)

# %%
import random
def get_training_and_testing_data(data, subjects, types, pca):
    if pca:
        size = data.shape[1]
    else:
        size = data.shape[0]*data.shape[1]
    training_data = []
    testing_data = []
    training_size = math.ceil(types*(3/5))
    testing_size = types - training_size
    subject = 0
    for i in range(subjects):
        temp = dict()
        temp['data'] = []

        for j in range(types):
            if pca:
                temp['data'].append((data[subject]))
                subject += 1
            else:
                temp['data'].append((data[:,:,j,i]).flatten())

        # random.shuffle(temp['data']) # shuffle the data
        tr = temp['data'][:training_size] # training batch
        te = temp['data'][training_size:] # testing batch
        training_data.append({'class': i, 'data':tr})
        testing_data.append({'class': i, 'data': te})
    
    return training_data, testing_data, training_size, testing_size

# %%
training_data, testing_data, training_size, testing_size = get_training_and_testing_data(projected, subjects=68, types=13, pca=True)

# %%
# print(training_data[0]['data'][8].shape)
# print(testing_data[0]['data'][0].shape)
print(training_size, testing_size)
# Out:
# 8 5

# %% [markdown]
# # Compute the Covariance and Mean of each class

# %%
mu = []
cov = []
for i in range(len(training_data)):
    matrix = np.array(training_data[i]['data'])
    mean = np.sum(matrix, axis=0)/matrix.shape[0]
    cov_ = (np.matmul((matrix - mean).T, (matrix-mean))) / matrix.shape[0]
    noise = 0.3*np.identity(cov_.shape[0])
    cov_ = cov_ + noise
    cov.append(cov_)
    mu.append(mean)
    if np.linalg.det(cov_) == 0 or np.linalg.det(cov_) == 0.0:
        print('alert - zero determinant')

# %%
# a = np.array(training_data[0]['data'])
# print(a.shape)
# mean = np.sum(a, axis=0)/len(training_data[0]['data'])
# mean

# %%
# a - mean

# %%
# b = np.array([[1,2,3],[1,2,3],[1,2,3],[1,2,3],[1,2,3]])
# mean = np.sum(b, axis=0) / 5
# print(mean)
# b - mean

# %%
usePCA = True

# %%
test_data = testing_data[0]['data']
print((-0.5)*math.log(np.linalg.det(cov[0])) - (0.5)*np.dot( test_data[0]-mu[0], np.dot( np.linalg.inv(cov[0]), (test_data[0]-mu[0]).T ) ))
print((-0.5)*math.log(np.linalg.det(cov[1])) - (0.5)*np.dot( test_data[1]-mu[0], np.dot( np.linalg.inv(cov[0]), (test_data[1]-mu[0]).T ) ))
# Out:
# -461187.1464606517
# -1913784.0216709638

# %% [markdown]
# # Find the maximum likelihood for each subject

# %%
score = 0
total_test_samples = len(testing_data)*testing_size
for i in range(subjects):
    for j in range(testing_size):
        test_data = testing_data[i]['data']
        likelihood_list = []
        for k in range(subjects):
            likelihood = (-0.5)*math.log(np.linalg.det(cov[k])) - (0.5)*np.dot( test_data[j]-mu[k], np.dot( np.linalg.inv(cov[k]), (test_data[j]-mu[k]).T ) )
            likelihood_list.append(likelihood)
        temp = np.array(likelihood_list)
        if np.argmax(temp) == i:
            score += 1
            print('Correct, score is now ', score)
        else:
            print('Incorrect Score for subject ', i)
print('Accuracy = ', (score*100/total_test_samples))
# Out:
# Correct, score is now  1
# Correct, score is now  2
# Correct, score is now  3
# Incorrect Score for subject  0
# Correct, score is now  4
# Correct, score is now  5
# Correct, score is now  6
# Correct, score is now  7
# Correct, score is now  8
# Correct, score is now  9
# Correct, score is now  10
# Correct, score is now  11
# Correct, score is now  12
# Correct, score is now  13
# Correct, score is now  14
# Correct, score is now  15
# Correct, score is now  16
# Correct, score is now  17
# Incorrect Score for subject  3
# Correct, score is now  18
# Correct, score is now  19
# Correct, score is now  20
# Correct, score is now  21
# Incorrect Score for subject  4
# Incorrect Score for subject  4
# Correct, score is now  22
# Correct, score is now  23
# Correct, score is now  24
# Incorrect Score for subject  5
# Correct, score is now  25
# Correct, score is now  26
# Correct, score is now  27
# Correct, score is now  28
# Incorrect Score for subject  6
# Correct, score is now  29
# Correct, score is now  30
# Correct, score is now  31
# Correct, score is now  32
# Correct, score is now  33
# Correct, score is now  34
# Correct, score is now  35
# Correct, score is now  36
# Correct, score is now  37
# Incorrect Score for subject  8
# Correct, score is now  38
# Correct, score is now  39
# Correct, score is now  40
# Correct, score is now  41
# Incorrect Score for subject  9
# Correct, score is now  42
# Correct, score is now  43
# Correct, score is now  44
# Correct, score is now  45
# Incorrect Score for subject  10
# Incorrect Score for subject  10
# Correct, score is now  46
# Correct, score is now  47
# Correct, score is now  48
# Incorrect Score for subject  11
# Correct, score is now  49
# Correct, score is now  50
# Correct, score is now  51
# Correct, score is now  52
# Correct, score is now  53
# Correct, score is now  54
# Correct, score is now  55
# Correct, score is now  56
# Correct, score is now  57
# Incorrect Score for subject  13
# Incorrect Score for subject  13
# Correct, score is now  58
# Correct, score is now  59
# Correct, score is now  60
# Correct, score is now  61
# Correct, score is now  62
# Correct, score is now  63
# Correct, score is now  64
# Correct, score is now  65
# Incorrect Score for subject  15
# Correct, score is now  66
# Correct, score is now  67
# Correct, score is now  68
# Incorrect Score for subject  16
# Incorrect Score for subject  16
# Incorrect Score for subject  16
# Correct, score is now  69
# Correct, score is now  70
# Correct, score is now  71
# Incorrect Score for subject  17
# Correct, score is now  72
# Correct, score is now  73
# Correct, score is now  74
# Correct, score is now  75
# Incorrect Score for subject  18
# Incorrect Score for subject  18
# Correct, score is now  76
# Correct, score is now  77
# Correct, score is now  78
# Correct, score is now  79
# Correct, score is now  80
# Correct, score is now  81
# Correct, score is now  82
# Correct, score is now  83
# Incorrect Score for subject  20
# Incorrect Score for subject  20
# Correct, score is now  84
# Correct, score is now  85
# Correct, score is now  86
# Correct, score is now  87
# Correct, score is now  88
# Correct, score is now  89
# Correct, score is now  90
# Correct, score is now  91
# Incorrect Score for subject  22
# Correct, score is now  92
# Correct, score is now  93
# Correct, score is now  94
# Correct, score is now  95
# Incorrect Score for subject  23
# Correct, score is now  96
# Correct, score is now  97
# Correct, score is now  98
# Correct, score is now  99
# Incorrect Score for subject  24
# Incorrect Score for subject  24
# Correct, score is now  100
# Correct, score is now  101
# Correct, score is now  102
# Incorrect Score for subject  25
# Correct, score is now  103
# Correct, score is now  104
# Correct, score is now  105
# Correct, score is now  106
# Incorrect Score for subject  26
# Correct, score is now  107
# Correct, score is now  108
# Correct, score is now  109
# Correct, score is now  110
# Correct, score is now  111
# Correct, score is now  112
# Correct, score is now  113
# Correct, score is now  114
# Correct, score is now  115
# Incorrect Score for subject  28
# Incorrect Score for subject  28
# Correct, score is now  116
# Correct, score is now  117
# Correct, score is now  118
# Incorrect Score for subject  29
# Correct, score is now  119
# Correct, score is now  120
# Correct, score is now  121
# Correct, score is now  122
# Incorrect Score for subject  30
# Correct, score is now  123
# Correct, score is now  124
# Correct, score is now  125
# Correct, score is now  126
# Incorrect Score for subject  31
# Correct, score is now  127
# Correct, score is now  128
# Correct, score is now  129
# Correct, score is now  130
# Incorrect Score for subject  32
# Correct, score is now  131
# Correct, score is now  132
# Correct, score is now  133
# Correct, score is now  134
# Incorrect Score for subject  33
# Correct, score is now  135
# Correct, score is now  136
# Correct, score is now  137
# Correct, score is now  138
# Correct, score is now  139
# Correct, score is now  140
# Correct, score is now  141
# Correct, score is now  142
# Correct, score is now  143
# Correct, score is now  144
# Correct, score is now  145
# Correct, score is now  146
# Correct, score is now  147
# Correct, score is now  148
# Incorrect Score for subject  36
# Correct, score is now  149
# Correct, score is now  150
# Correct, score is now  151
# Correct, score is now  152
# Incorrect Score for subject  37
# Correct, score is now  153
# Correct, score is now  154
# Correct, score is now  155
# Correct, score is now  156
# Correct, score is now  157
# Correct, score is now  158
# Correct, score is now  159
# Correct, score is now  160
# Correct, score is now  161
# Incorrect Score for subject  39
# Correct, score is now  162
# Correct, score is now  163
# Correct, score is now  164
# Correct, score is now  165
# Incorrect Score for subject  40
# Correct, score is now  166
# Correct, score is now  167
# Correct, score is now  168
# Correct, score is now  169
# Correct, score is now  170
# Correct, score is now  171
# Correct, score is now  172
# Correct, score is now  173
# Correct, score is now  174
# Incorrect Score for subject  42
# Correct, score is now  175
# Correct, score is now  176
# Correct, score is now  177
# Correct, score is now  178
# Incorrect Score for subject  43
# Correct, score is now  179
# Correct, score is now  180
# Correct, score is now  181
# Correct, score is now  182
# Incorrect Score for subject  44
# Correct, score is now  183
# Correct, score is now  184
# Correct, score is now  185
# Correct, score is now  186
# Incorrect Score for subject  45
# Incorrect Score for subject  45
# Correct, score is now  187
# Correct, score is now  188
# Correct, score is now  189
# Incorrect Score for subject  46
# Correct, score is now  190
# Correct, score is now  191
# Correct, score is now  192
# Correct, score is now  193
# Correct, score is now  194
# Correct, score is now  195
# Correct, score is now  196
# Correct, score is now  197
# Correct, score is now  198
# Correct, score is now  199
# Incorrect Score for subject  48
# Correct, score is now  200
# Correct, score is now  201
# Correct, score is now  202
# Correct, score is now  203
# Correct, score is now  204
# Correct, score is now  205
# Correct, score is now  206
# Correct, score is now  207
# Incorrect Score for subject  50
# Correct, score is now  208
# Correct, score is now  209
# Correct, score is now  210
# Correct, score is now  211
# Correct, score is now  212
# Correct, score is now  213
# Correct, score is now  214
# Correct, score is now  215
# Correct, score is now  216
# Correct, score is now  217
# Incorrect Score for subject  52
# Correct, score is now  218
# Correct, score is now  219
# Correct, score is now  220
# Correct, score is now  221
# Incorrect Score for subject  53
# Correct, score is now  222
# Correct, score is now  223
# Correct, score is now  224
# Incorrect Score for subject  54
# Correct, score is now  225
# Correct, score is now  226
# Correct, score is now  227
# Correct, score is now  228
# Correct, score is now  229
# Correct, score is now  230
# Correct, score is now  231
# Correct, score is now  232
# Correct, score is now  233
# Incorrect Score for subject  56
# Correct, score is now  234
# Correct, score is now  235
# Correct, score is now  236
# Correct, score is now  237
# Correct, score is now  238
# Correct, score is now  239
# Correct, score is now  240
# Correct, score is now  241
# Correct, score is now  242
# Incorrect Score for subject  58
# Incorrect Score for subject  58
# Correct, score is now  243
# Correct, score is now  244
# Correct, score is now  245
# Incorrect Score for subject  59
# Correct, score is now  246
# Correct, score is now  247
# Correct, score is now  248
# Correct, score is now  249
# Correct, score is now  250
# Correct, score is now  251
# Correct, score is now  252
# Correct, score is now  253
# Correct, score is now  254
# Incorrect Score for subject  61
# Correct, score is now  255
# Correct, score is now  256
# Correct, score is now  257
# Correct, score is now  258
# Correct, score is now  259
# Correct, score is now  260
# Correct, score is now  261
# Correct, score is now  262
# Correct, score is now  263
# Incorrect Score for subject  63
# Correct, score is now  264
# Correct, score is now  265
# Correct, score is now  266
# Correct, score is now  267
# Correct, score is now  268
# Correct, score is now  269
# Correct, score is now  270
# Correct, score is now  271
# Correct, score is now  272
# Incorrect Score for subject  65
# Correct, score is now  273
# Correct, score is now  274
# Correct, score is now  275
# Correct, score is now  276
# Incorrect Score for subject  66
# Incorrect Score for subject  66
# Correct, score is now  277
# Correct, score is now  278
# Correct, score is now  279
# Incorrect Score for subject  67
# Correct, score is now  280
# Accuracy =  82.3529411764706

# %%
print('Accuracy = ', (score*100/total_test_samples))
# Out:
# Accuracy =  82.3529411764706
